# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
import random
import time

class Kumanda():
    def __init__(self, tv_durum="Kapalı", tv_ses=0, tv_kanal_listesi=["TRT"], tv_kanal="TRT"):
        self.tv_durum = tv_durum
        self.tv_ses = tv_ses
        self.tv_kanal_listesi = tv_kanal_listesi
        self.tv_kanal = tv_kanal

    def tv_ac(self):
        if self.tv_durum == "Açık":
            print("Televizyon zaten açık.")
        else:
            print("Televizyon açılıyor...")
            self.tv_durum = "Açık"
            time.sleep(1)
            print("Televizyon açıldı.")

    def tv_kapat(self):
        if self.tv_durum == "Kapalı":
            print("Televizyon zaten kapalı.")
        else:
            print("Televizyon kapatılıyor...")
            self.tv_durum = "Kapalı"
            time.sleep(1)
            print("Televizyon kapandı.")

    def ses_ayarları(self):
        while True:
            cevap = input("Sesi azalt: '<'\nSesi artır: '>'\nÇıkış: 'q'")
            if cevap == "<":
                if self.tv_ses != 0:
                    self.tv_ses -= 1
                    print("Ses:", self.tv_ses)
            elif cevap == ">":
                if self.tv_ses != 31:
                    self.tv_ses += 1
                    print("Ses:", self.tv_ses)
            else:
                print("Ses güncellendi:", self.tv_ses)
                break

    def kanal_ekle(self, kanal):
        print("Kanal ekleniyor...")
        time.sleep(1)
        self.tv_kanal_listesi.append(kanal)
        print("Kanal eklendi.")

    def kanal_sayisi(self):
        print("Toplam", len(self.tv_kanal_listesi), "kanal var.")

    def rastgele_kanal(self):
        rastgele = random.randint(0, len(self.tv_kanal_listesi)-1)
        self.tv_kanal = self.tv_kanal_listesi[rastgele]
        print("Şu anki kanal:", self.tv_kanal)

    def televizyon_bilgileri(self):
        print("Tv durumu:", self.tv_durum)
        print("Ses:", self.tv_ses)
        print("Kanal listesi:", self.tv_kanal_listesi)
        print("Şu anki kanal:", self.tv_kanal)


kumanda = Kumanda()

print("""Televizyon Kumandası

1. Tv Aç
2. Tv Kapat
3. Ses Ayarları
4. Kanal Ekle
5. Kanal Sayısını Öğrenme
6. Rastgele Kanala Geçme
7. Televizyon Bilgileri

Çıkmak için 'q' ya basın.
""")

while True:
    işlem = input("İşlemi seçiniz:")

    if işlem == "q":
        print("Programdan çıkılıyor...")
        break

    elif işlem == "1":
        kumanda.tv_ac()

    elif işlem == "2":
        kumanda.tv_kapat()

    elif işlem == "3":
        kumanda.ses_ayarları()

    elif işlem == "4":
       kanal_isimleri =input("eklemek istediğiniz kanal ismini , le ayırarak gir")
       kanal_listesi= kanal_isimleri.split(",")
       for i in kanal_listesi
       kumanda.kanal_ekle(i)

    elif işlem == "5":
        print("kanal sayısı:",len(kumanda))

    elif işlem == "6":
        kumanda.rastgele_kanal()

    elif işlem == "7":
        print(kumanda)
    else:
        print("geçersiz işlem")
# Out:
#   Cell In[2], line 99
#     for i in kanal_listesi
#                           ^
# SyntaxError: expected ':'
